# %%
#ANALYSE DE DONNEES
import numpy as np  #manipulation des tableaux et calculs scientifiques 
import pandas as pd # manipulation, nettoyage, analyse de bases de donnees (documentation de 3707 pages!)

#VISUALISATION
import seaborn as sns #visualisation de donnees avec python
import matplotlib.pylab as plt #visualisation de donnees avec python

#DECISION (loi de probabilités: plus de 180 lois (une dizaine pour vous))
import scipy as sp    #faire de la statistique decisionnelle, probabilités, algebre, optimation
import yfinance as yf # pour pouvoir telecharge tous le dataset de la finance
import numpy as np  #manipulation des tableaux et calculs scientifiques 
import pandas as pd # manipulation, nettoyage, analyse de bases de donnees (documentation de 3707 pages!)

#VISUALISATION
import seaborn as sns #visualisation de donnees avec python
import matplotlib.pylab as plt #visualisation de donnees avec python

#DECISION (loi de probabilités: plus de 180 lois (une dizaine pour vous))
import scipy as sp    #faire de la statistique decisionnelle, probabilités, algebre, optimation

# %%
data=yf.download("TSLA",start="2010-06-01",end="2024-05-03")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-04-26  168.850006  172.119995  166.369995  168.289993  168.289993
# 2024-04-29  188.419998  198.869995  184.539993  194.050003  194.050003
# 2024-04-30  186.979996  190.949997  182.839996  183.279999  183.279999
# 2024-05-01  182.000000  185.860001  179.009995  179.990005  179.990005
# 2024-05-02  182.860001  184.600006  176.020004  180.009995  180.009995
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
#On a 3486 ligne et 6 colonnes

# %%
data["Close"]  #affiche tous les derniers close de tesla depuis 14 ans
# Out:
# Date
# 2010-06-29      1.592667
# 2010-06-30      1.588667
# 2010-07-01      1.464000
# 2010-07-02      1.280000
# 2010-07-06      1.074000
#                  ...
# 2024-04-26    168.289993
# 2024-04-29    194.050003
# 2024-04-30    183.279999
# 2024-05-01    179.990005
# 2024-05-02    180.009995
# Name: Close, Length: 3485, dtype: float64

# %%
data["Close"].plot()  #afficher la courbe de l'evolution depuis 14 ans
# Out:
# <Axes: xlabel='Date'>

# %%
data.columns  # il m'a indique que ma dataset est composée de sete colonnes
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [raw]
# 2)Data infos

# %%
data.sample  # on voit seulement les cinq échantillon
# Out:
# <bound method NDFrame.sample of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-04-26  168.850006  172.119995  166.369995  168.289993  168.289993
# 2024-04-29  188.419998  198.869995  184.539993  194.050003  194.050003
# 2024-04-30  186.979996  190.949997  182.839996  183.279999  183.279999
# 2024-05-01  182.000000  185.860001  179.009995  179.990005  179.990005
# 2024-05-02  182.860001  184.600006  176.020004  180.009995  180.009995
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# ...

# %%
data.info  # on constacte qu'on a 3486 ligne et 6 colonnes
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-04-26  168.850006  172.119995  166.369995  168.289993  168.289993
# 2024-04-29  188.419998  198.869995  184.539993  194.050003  194.050003
# 2024-04-30  186.979996  190.949997  182.839996  183.279999  183.279999
# 2024-05-01  182.000000  185.860001  179.009995  179.990005  179.990005
# 2024-05-02  182.860001  184.600006  176.020004  180.009995  180.009995
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# ...

# %%
data.value_counts()
# Out:
# Open        High        Low         Close       Adj Close   Volume
# 1.076000    1.168000    1.038000    1.164000    1.164000    115671000    1
# 23.798668   23.899332   23.578667   23.704666   23.704666   53107500     1
# 23.693333   24.915333   23.633333   24.722000   24.722000   181098000    1
# 23.704000   23.809999   23.213333   23.454000   23.454000   75927000     1
# 23.731333   24.200001   23.608667   23.976667   23.976667   74086500     1
#                                                                         ..
# 13.976000   14.013333   13.150000   13.423333   13.423333   152689500    1
# 13.976667   13.998667   13.640667   13.720667   13.720667   50598000     1
# 13.982000   14.302667   13.866667   14.265333   14.265333   77629500     1
# 13.983333   14.054000   13.812000   13.878000   13.878000   46107000     1
# 411.470001  414.496674  405.666656  409.970001  409.970001  76192200     1
# Name: count, Length: 3485, dtype: int64

# %%
data ["Close"].describe() # on vois que 75% de  la cloture est de 141.920826  et 73.356458
# Out:
# count    3485.000000
# mean       73.325530
# std       101.907856
# min         1.053333
# 25%        11.245333
# 50%        17.243999
# 75%       141.893326
# max       409.970001
# Name: Close, dtype: float64

# %%
Analyse universaire
# Out:
#   Cell In[12], line 1
#     Analyse universaire
#             ^
# SyntaxError: invalid syntax

# %%
data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-04-19', '2024-04-22', '2024-04-23', '2024-04-24',
#                '2024-04-25', '2024-04-26', '2024-04-29', '2024-04-30',
#                '2024-05-01', '2024-05-02'],
#               dtype='datetime64[ns]', name='Date', length=3485, freq=None)

# %%
data["Close"].plot(figsize=(10,5))  # on  a une ligne droite si que on peut dire que  l'actin tesla grimmpe chaque jour
# Out:
# <Axes: xlabel='Date'>

# %%
Donnée manquantes

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#il y a aucunne valeur manquantes pour les actions de tesla

# %%
Dispersion
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Dispersion
#
# NameError: name 'Dispersion' is not defined

# %%
dispersion_moyenne=data["Close"].std()/data["Close"].mean()*100
dispersion_moyenne

# %%
#la cloture se varie lentement donc la variation est dispersée  car la dispersion est superieur à 50%

# %%
#maintenant on va calculer la dispersion de la mediane

# %%
Q1=data["Close"].quantile(0.25)
Q3= data["Close"].quantile(0.75)
IQR=Q3-Q1 #écrat interquantile

# %%
dispersion_mediane=IQR/data["Close"].median()*100
dispersion_mediane
# Out:
# 757.6432209372113

# %%
#la dispersion mediane est heterogene car elle est superieur à 100 %

# %%
Donnée Aberrantes
# Out:
#   Cell In[21], line 1
#     Donnée Aberrantes
#            ^
# SyntaxError: invalid syntax

# %%
data["Close"].plot(kind="box")
# Out:
# <Axes: >

# %%
#le donnée aberrante est anormal comme on peut voir beaucoup de valeur aberrante

# %%
data["Close"].plot(kind="box")
# Out:
# <Axes: >

# %%
data.plot(kind="box")
# Out:
# <Axes: >

# %%
sns.boxplot(x="Close", data=data)  #
# Out:
# <Axes: xlabel='Close'>

# %%
#on  a beaucoup de  valeur aberrantes

# %%
Test de normalite
# Out:
#   Cell In[28], line 1
#     Test de normalite
#          ^
# SyntaxError: invalid syntax

# %%
data["Close"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
#la droite est symétrique

# %%
data["Close"].skew()
# Out:
# 1.315756713208777

# %%
#on peut observe que  le marcje se grimmpre progessiviment tous les jours

# %%
Test de stationalité
# Out:
#   Cell In[33], line 1
#     Test de stationalité
#          ^
# SyntaxError: invalid syntax

# %%
from statsmodels.tsa.stattools import adfuller
adf_test = adfuller(data['Close'])
adf_test
# Out:
# (-1.2910016914484335,
#  0.6332789299400025,
#  29,
#  3455,
#  {'1%': -3.4322441143618896,
#   '5%': -2.86237691138194,
#   '10%': -2.5672155030461945},
#  20410.080901533765)

# %%
data["Close"].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
#on peut observe d'aprés la courbe on va que le prix de la fermenture grimper environ à partir de mars 2020

# %%
#h0: LA SERIE EST TEMPORELLE
#pvalue=la veracité de H0

#CONCLUSION: si pvalue>5% alors notre SERIE est TEMPORELLE
#CONCLUSION: si pvalue<5% alors notre SERIE N'est PAS TEMPORELLE

# %%
from statsmodels.tsa.stattools import adfuller as DukeyFuller_test
DukeyFuller_test(data["Close"])[1]  #pvalue
# Out:
# 0.6332789299400025

# %%
#pvalue = 63% superieur a 5% donc on accepte HO , la série est temporelle

# %%
La decomposition de la serie
# Out:
#   Cell In[40], line 1
#     La decomposition de la serie
#        ^
# SyntaxError: invalid syntax

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

y=data['Close']
# Seasonal decomposition
decomposition = seasonal_decompose(y, model='additive', period=360)
fig = decomposition.plot()

fig.set_figwidth(12)
fig.set_figheight(8)
fig.suptitle('Decomposition of Additive Time Series')

# par pas de 12
for ax in fig.axes:
    ax.xaxis.set_major_locator(plt.MaxNLocator(6))
    plt.setp(ax.get_xticklabels(), rotation=90)

plt.show()

# %%
COLERRACTION PARTIELLE
# Out:
#   Cell In[42], line 1
#     COLERRACTION PARTIELLE
#                  ^
# SyntaxError: invalid syntax

# %%
y.head() #y(t)
# Out:
# Date
# 2010-06-29    1.592667
# 2010-06-30    1.588667
# 2010-07-01    1.464000
# 2010-07-02    1.280000
# 2010-07-06    1.074000
# Name: Close, dtype: float64

# %%
y1=y.shift(1)   #y(t-1)
y1.head(5)  #shift=decalage
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30    1.592667
# 2010-07-01    1.588667
# 2010-07-02    1.464000
# 2010-07-06    1.280000
# Name: Close, dtype: float64

# %%
#pour predire le present , il faut determiner regarde le passe pour pouvoir determine le present
y.corr(y1)
# Out:
# 0.9989282864482659

# %%
La correlation est de 100 %
# Out:
#   Cell In[46], line 1
#     La correlation est de 100 %
#        ^
# SyntaxError: invalid syntax

# %%
LA CONVARIANCE DE LA SERIE
# Out:
#   Cell In[47], line 1
#     LA CONVARIANCE DE LA SERIE
#        ^
# SyntaxError: invalid syntax

# %%
data.cov()["Close"]
# Out:
# Open         1.038573e+04
# High         1.061948e+04
# Low          1.013789e+04
# Close        1.038521e+04
# Adj Close    1.038521e+04
# Volume       8.588933e+08
# Name: Close, dtype: float64

# %%
#la convariance de la  fermenture est positive

# %%
data.corr()["Close"].abs().sort_values().plot(kind="bar", figsize=(10,5))
# Out:
# <Axes: >

# %%
# Modele de lissage

# %%
y=data["Close"]
y
# Out:
# Date
# 2010-06-29      1.592667
# 2010-06-30      1.588667
# 2010-07-01      1.464000
# 2010-07-02      1.280000
# 2010-07-06      1.074000
#                  ...
# 2024-04-26    168.289993
# 2024-04-29    194.050003
# 2024-04-30    183.279999
# 2024-05-01    179.990005
# 2024-05-02    180.009995
# Name: Close, Length: 3485, dtype: float64

# %%
y.plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
y
# Out:
# Date
# 2010-06-29      1.592667
# 2010-06-30      1.588667
# 2010-07-01      1.464000
# 2010-07-02      1.280000
# 2010-07-06      1.074000
#                  ...
# 2024-04-26    168.289993
# 2024-04-29    194.050003
# 2024-04-30    183.279999
# 2024-05-01    179.990005
# 2024-05-02    180.009995
# Name: Close, Length: 3485, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing  #recuperer notre modele depuis python
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
y=data["Close"]

# %%
y.shape
# Out:
# (3485,)

# %%
#complifions notre modele en lui donnant d'autres informations comme la saisonnalité
y_train= y[0:3000]  #le modele va s'entrainer avec 100 donnees   (souvent on prends 75-80-85%)
y_test= y[3000:] #On garde une vingtaine de donnees pour tester ou valider le modele
model = ExponentialSmoothing(y_train, seasonal_periods=365, trend='add', seasonal='add').fit()
y_prediction = model.forecast(485)
y_prediction
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 3000    235.065739
# 3001    234.574939
# 3002    236.213689
# 3003    237.963854
# 3004    236.064668
#            ...
# 3480    275.882659
# 3481    274.669632
# 3482    275.897856
# ...

# %%
plt.figure(figsize=(15,3))
plt.plot(y_test.values, label='Close', color='green')

plt.plot(y_prediction.values, label='Close PREDICT ', color='red')

plt.ylabel('Close (en year)')
plt.xlabel('Temps')
plt.title("Prédiction de l'action tesla" )
plt.legend(loc='best')
plt.show()

# %%
resultat=pd.DataFrame()
resultat["realite"]=y_test
resultat["prevision"]=y_prediction
resultat["erreur"]=(resultat["prevision"]-resultat["realite"])/resultat["realite"]*100
resultat
# Out:
#                realite  prevision  erreur
# Date
# 2022-05-27  253.210007        NaN     NaN
# 2022-05-31  252.753326        NaN     NaN
# 2022-06-01  246.789993        NaN     NaN
# 2022-06-02  258.333344        NaN     NaN
# 2022-06-03  234.516663        NaN     NaN
# ...                ...        ...     ...
# 2024-04-26  168.289993        NaN     NaN
# 2024-04-29  194.050003        NaN     NaN
# 2024-04-30  183.279999        NaN     NaN
# 2024-05-01  179.990005        NaN     NaN
# 2024-05-02  180.009995        NaN     NaN
#
# [485 rows x 3 columns]

# %%
ARIMA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 ARIMA
#
# NameError: name 'ARIMA' is not defined

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing as HWES
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import grangercausalitytests

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
#choix des parametres du modele
p,d,q,P,D,Q,s=1,0,1,2,0,0,12   #j'ai rajouté un mouvement brownien (un petit bruit q=1)

#on instancie le modele SARIMAX
model = SARIMAX(y[0:3485], order=(p,d,q), seasonal_order = (P,Q,D, s))
               #variables 
#on entraine le modele
results = model.fit()
#les resultats fournis par le modele
results.summary()
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                               Close   No. Observations:                 3485
# Model:             SARIMAX(1, 0, 1)x(2, 0, [], 12)   Log Likelihood              -10335.220
# Date:                             Sat, 18 May 2024   AIC                          20680.440
# ...

# %%
results.resid.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
#la courbe est symétrique

# %%
results.resid.kurtosis()   #il pourrait y avoir certains erreurs
# Out:
# 18.89158164463215

# %%
results.resid.plot(kind="box")
# Out:
# <Axes: >

# %%
#on voit que il y a beaucaup de valeur erronée

# %%
from scipy.stats import shapiro

# %%
shapiro(results.resid)
# Out:
# ShapiroResult(statistic=0.6419210433959961, pvalue=0.0)

# %%
# on voit que pvalue est inferieur à  5%
#conclusion: il ne faut pas valider le modele à ce stade, il faut l'ameliorer!

# %%
data.head(4)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
model_arima = ARIMA(data['Close'], order=(2, 0, 2))
model_arima_fit = model_arima.fit()
print(model_arima_fit.summary())
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
# Prévision ARIMA
data['ARIMA_Forecast'] = model_arima_fit.predict(start=0, end=len(data)-1)

# %%
# 5. Processus non stationnaires: ARIMA(p,q,d) et SARIMA(p,q,d)(P,Q,D,S)
model_sarima = SARIMAX(data['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_sarima_fit = model_sarima.fit()
print(model_sarima_fit.summary())
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Close   No. Observations:                 3485
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood              -10346.274
# Date:                            Sat, 18 May 2024   AIC                          20702.548
# Time:                                    20:33:30   BIC                          20733.310
# ...

# %%
# Prévision SARIMA
data['SARIMA_Forecast'] = model_sarima_fit.predict(start=0, end=len(data)-1)

# %%
Tests de causalité de Granger

# %%
symbols =['TSLA', 'META','MSFT','GOOG','NVDA',"APLE"]
data=yf.download(symbols,start="2010-06-01",end="2024-05-04")
data=data.Close
data
# Out:
# [*********************100%%**********************]  6 of 6 completed
# Ticker       APLE        GOOG        META        MSFT        NVDA        TSLA
# Date
# 2010-06-01    NaN   12.014218         NaN   25.889999    3.145000         NaN
# 2010-06-02    NaN   12.288191         NaN   26.459999    3.180000         NaN
# 2010-06-03    NaN   12.592799         NaN   26.860001    3.175000         NaN
# 2010-06-04    NaN   12.421441         NaN   25.790001    3.025000         NaN
# 2010-06-07    NaN   12.092674         NaN   25.290001    2.875000         NaN
# ...           ...         ...         ...         ...         ...         ...
# 2024-04-29  15.08  167.899994  432.619995  402.250000  877.570007  194.050003
# 2024-04-30  14.76  164.639999  430.170013  389.329987  864.020020  183.279999
# 2024-05-01  14.85  165.570007  439.190002  394.940002  830.409973  179.990005
# 2024-05-02  14.67  168.460007  441.679993  397.839996  858.169983  180.009995
# ...

# %%
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests

# Liste des symboles d'actions à télécharger
symbols = ['TSLA', 'META', 'MSFT', 'GOOG', 'NVDA', 'APLE']

# Téléchargement des données des cours de clôture des actions
data = yf.download(symbols, start="2020-06-01", end="2024-05-04")['Close']
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
data
# Out:
# Ticker           APLE        GOOG        META        MSFT        NVDA  \
# Date
# 2010-06-01  16.421037   12.014218  166.268654   25.889999    3.145000
# 2010-06-02  16.421037   12.288191  166.268654   26.459999    3.180000
# 2010-06-03  16.421037   12.592799  166.268654   26.860001    3.175000
# 2010-06-04  16.421037   12.421441  166.268654   25.790001    3.025000
# 2010-06-07  16.421037   12.092674  166.268654   25.290001    2.875000
# ...               ...         ...         ...         ...         ...
# 2024-04-29  15.080000  167.899994  432.619995  402.250000  877.570007
# 2024-04-30  14.760000  164.639999  430.170013  389.329987  864.020020
# 2024-05-01  14.850000  165.570007  439.190002  394.940002  830.409973
# 2024-05-02  14.670000  168.460007  441.679993  397.839996  858.169983
# 2024-05-03  14.680000  168.990005  451.959991  406.660004  887.890015
#
# Ticker            TSLA
# Date
# 2010-06-01   73.356472
# 2010-06-02   73.356472
# 2010-06-03   73.356472
# ...

# %%
# Appliquer le test de causalité de Granger pour chaque paire de variables
for variable1 in symbols:
    for variable2 in symbols:
        if variable1 != variable2:
            print(f"Test de causalité de Granger entre {variable1} et {variable2}:")
            granger_results = grangercausalitytests(data[[variable1, variable2]], maxlag=12, verbose=True)
            print("\n")
# Out:
# Test de causalité de Granger entre TSLA et META:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1578  , p=0.6913  , df_denom=985, df_num=1
# ssr based chi2 test:   chi2=0.1583  , p=0.6908  , df=1
# likelihood ratio test: chi2=0.1583  , p=0.6908  , df=1
# parameter F test:         F=0.1578  , p=0.6913  , df_denom=985, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4348  , p=0.6475  , df_denom=982, df_num=2
# ssr based chi2 test:   chi2=0.8740  , p=0.6460  , df=2
# likelihood ratio test: chi2=0.8736  , p=0.6461  , df=2
# parameter F test:         F=0.4348  , p=0.6475  , df_denom=982, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2812  , p=0.8390  , df_denom=979, df_num=3
# ssr based chi2 test:   chi2=0.8495  , p=0.8376  , df=3
# likelihood ratio test: chi2=0.8491  , p=0.8377  , df=3
# parameter F test:         F=0.2812  , p=0.8390  , df_denom=979, df_num=3
#
# ...

# %%
data=data.select_dtypes(exclude=['object']) # je prends toutes les donnees numeriques
data=data.fillna(data.mean()) # j impute les valeurs manquantes par la moyenne
data.head()
# Out:
# Ticker       APLE       GOOG        META        MSFT       NVDA       TSLA
# Date
# 2020-06-01  10.74  71.591003  231.910004  182.830002  88.062500  59.873333
# 2020-06-02  11.05  71.960999  232.720001  184.910004  88.252502  58.770668
# 2020-06-03  11.46  71.819000  230.160004  185.360001  87.695000  58.863998
# 2020-06-04  11.95  70.609001  226.289993  182.919998  87.665001  57.625332
# 2020-06-05  12.67  71.919502  230.770004  187.199997  89.199997  59.043999

# %%
def grangers_causation_matrix(data, variables, maxlag):
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0]['ssr_ftest'][1], 4) for i in range(maxlag)]
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
matrice_causalite = grangers_causation_matrix(data, variables=data.columns, maxlag=12)
print(matrice_causalite)
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ...

# %%
# Vérifier les noms des colonnes dans matrice_causalite
print(matrice_causalite.columns)

# Ensuite, vous pouvez essayer de sélectionner la colonne appropriée en fonction des noms de colonnes dans matrice_causalite

matrice_causalite.T['TSLA_y'].sort_values()[:-1].plot(kind="bar", figsize=(15,3))
# Out:
# Index(['APLE_x', 'GOOG_x', 'META_x', 'MSFT_x', 'NVDA_x', 'TSLA_x'], dtype='object')
# <Axes: >

# %%
matrice_causalite=grangers_causation_matrix(data, variables = data.columns, maxlag=4)
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(matrice_causalite, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Toutes les variables sont interessantes

# %%
data.columns
# Out:
# Index(['APLE', 'GOOG', 'META', 'MSFT', 'NVDA', 'TSLA'], dtype='object', name='Ticker')

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Example variables
p, d, q = 1, 1, 1
P, Q, D, frequence = 1, 1, 1, 12
#on prend les 2 derniers mois du passé (p,q), et les deux dernieres  saisons (P,Q)
#on instancie le modele SARIMAX

exog_vars = ['APLE', 'GOOG', 'META', 'MSFT', 'NVDA', 'TSLA']
exog = data[exog_vars]
#localisation 
exog = exog.loc[y.index]

model = SARIMAX(y, 
                order=(p, d, q), 
                seasonal_order=(P, Q, D, frequence), 
                exog=exog)
results = model.fit()

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[249], line 17
#      14 exog = data[exog_vars]
#      16 # Align the indices
# ---> 17 exog = exog.loc[y.index]
#      19 # Instantiate and fit the SARIMAX model
#      20 model = SARIMAX(y,
#      21                 order=(p, d, q),
#      22                 seasonal_order=(P, Q, D, frequence),
#      23                 exog=exog)
#
# File ~\OneDrive\Bureau\ANACO\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\OneDrive\Bureau\ANACO\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
# ...

# %%
shapiro(results.resid)
#pvalue>5% donc on ne peut pas rejeter l'hypothese de normalité des residus
#conslusion sur la base des statistiques: ON VALIDE LE MODELE
# Out:
# ShapiroResult(statistic=0.6419210433959961, pvalue=0.0)

# %%
data
# Out:
# Ticker       APLE        GOOG        META        MSFT        NVDA        TSLA
# Date
# 2020-06-01  10.74   71.591003  231.910004  182.830002   88.062500   59.873333
# 2020-06-02  11.05   71.960999  232.720001  184.910004   88.252502   58.770668
# 2020-06-03  11.46   71.819000  230.160004  185.360001   87.695000   58.863998
# 2020-06-04  11.95   70.609001  226.289993  182.919998   87.665001   57.625332
# 2020-06-05  12.67   71.919502  230.770004  187.199997   89.199997   59.043999
# ...           ...         ...         ...         ...         ...         ...
# 2024-04-29  15.08  167.899994  432.619995  402.250000  877.570007  194.050003
# 2024-04-30  14.76  164.639999  430.170013  389.329987  864.020020  183.279999
# 2024-05-01  14.85  165.570007  439.190002  394.940002  830.409973  179.990005
# 2024-05-02  14.67  168.460007  441.679993  397.839996  858.169983  180.009995
# 2024-05-03  14.68  168.990005  451.959991  406.660004  887.890015  181.190002
#
# [989 rows x 6 columns]

# %%
data.query
# Out:
# <bound method DataFrame.query of Ticker       APLE        GOOG        META        MSFT        NVDA        TSLA
# Date
# 2020-06-01  10.74   71.591003  231.910004  182.830002   88.062500   59.873333
# 2020-06-02  11.05   71.960999  232.720001  184.910004   88.252502   58.770668
# 2020-06-03  11.46   71.819000  230.160004  185.360001   87.695000   58.863998
# 2020-06-04  11.95   70.609001  226.289993  182.919998   87.665001   57.625332
# 2020-06-05  12.67   71.919502  230.770004  187.199997   89.199997   59.043999
# ...           ...         ...         ...         ...         ...         ...
# 2024-04-29  15.08  167.899994  432.619995  402.250000  877.570007  194.050003
# 2024-04-30  14.76  164.639999  430.170013  389.329987  864.020020  183.279999
# 2024-05-01  14.85  165.570007  439.190002  394.940002  830.409973  179.990005
# 2024-05-02  14.67  168.460007  441.679993  397.839996  858.169983  180.009995
# 2024-05-03  14.68  168.990005  451.959991  406.660004  887.890015  181.190002
# ...

# %%
data.shape
# Out:
# (989, 6)

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Division des données en deux périodes (pour facebook, on pouvait diviser en 4 ou 3)
period1 = data["TSLA"].iloc[0:600]
period2 = data["TSLA"].iloc[600:]
#l'objectif est de savoir si nos donnees ont drastiquement changer d'evolution au cours de ces 2 periodes

# %%
plt.figure(figsize=(5, 6))
sns.kdeplot(period1, shade=True, label='Distribution 1')
sns.kdeplot(period2, shade=True, label='Distribution 2')

plt.xlabel('Valeur')
plt.legend()
plt.show()
# Out:
# C:\Users\nadin\AppData\Local\Temp\ipykernel_7448\2539253781.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(period1, shade=True, label='Distribution 1')
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nadin\AppData\Local\Temp\ipykernel_7448\2539253781.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(period2, shade=True, label='Distribution 2')
# ...

# %%
target = data
target.head()
# Out:
# Ticker       APLE       GOOG        META        MSFT       NVDA       TSLA
# Date
# 2020-06-01  10.74  71.591003  231.910004  182.830002  88.062500  59.873333
# 2020-06-02  11.05  71.960999  232.720001  184.910004  88.252502  58.770668
# 2020-06-03  11.46  71.819000  230.160004  185.360001  87.695000  58.863998
# 2020-06-04  11.95  70.609001  226.289993  182.919998  87.665001  57.625332
# 2020-06-05  12.67  71.919502  230.770004  187.199997  89.199997  59.043999

# %%
exog.head()
# Out:
# Ticker       APLE       GOOG        META        MSFT       NVDA       TSLA
# Date
# 2020-06-01  10.74  71.591003  231.910004  182.830002  88.062500  59.873333
# 2020-06-02  11.05  71.960999  232.720001  184.910004  88.252502  58.770668
# 2020-06-03  11.46  71.819000  230.160004  185.360001  87.695000  58.863998
# 2020-06-04  11.95  70.609001  226.289993  182.919998  87.665001  57.625332
# 2020-06-05  12.67  71.919502  230.770004  187.199997  89.199997  59.043999

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Supposons que `target` et `exog` soient des DataFrames pandas

# Taille du test
n = 6

# Sélectionner une seule colonne de `target`, par exemple la première colonne
target_column = target.iloc[:, 0]

# Préparation des ensembles d'entraînement et de test
target_train = target_column[:-n]
target_test = target_column[-n:]

exog_train = exog.head(len(exog) - n)
exog_test = exog.tail(n)

# Définir la configuration du modèle
p, d, q = 1, 1, 1  # Exemples de valeurs, ajustez selon votre cas
P, D, Q = 1, 1, 1  # Exemples de valeurs, ajustez selon votre cas
frequence = 12  # Par exemple, pour des données mensuelles

my_order = (p, d, q)
my_seasonal_order = (P, D, Q, frequence)

# Définir et ajuster le modèle SARIMAX
model = SARIMAX(target_train,
                exog=exog_train,
                order=my_order,
                seasonal_order=my_seasonal_order)
results4 = model.fit()

# Afficher le résumé du modèle
print(results4.summary())
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ...
# Dep. Variable:                               APLE   No. Observations:                  983
# ...

# %%
results4.resid.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
#la courbe est asymetrique car il y a une partie que par vers la gauche

# %%
shapiro(results4.resid)
# Out:
# ShapiroResult(statistic=0.8433614373207092, pvalue=4.7908556847988906e-30)

# %%
#Le pvalue est superieur à 5% donc on accepte H0

# %%
y.head(1)
# Out:
# Date
# 2010-06-29    1.592667
# Name: Close, dtype: float64

# %%
predictions=results4.forecast(steps=989,start_index = "2020-06-01", exog = exog)
predictions
# Out:
# C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 983     10.74
# 984     11.05
# 985     11.46
# 986     11.95
# 987     12.67
#         ...
# 1967    15.08
# 1968    14.76
# 1969    14.85
# 1970    14.67
# 1971    14.68
# Name: predicted_mean, Length: 989, dtype: float64

# %%
yhatsarimax=predictions

# %%
target = data[["TSLA", "META"]]
predictions = data["TSLA"]

# %%
import matplotlib.pyplot as plt

# Tracer les séries temporelles
plt.figure(figsize=(14, 6))
plt.plot(target["TSLA"], label='ACTION', color='green')
plt.plot(predictions, label='ACTION PREDICT', color='red')

plt.ylabel('Action (en GWh)')
plt.xlabel('Temps')
plt.title('Prédiction de l\'action au cours du temps par la méthode SARIMAX')
plt.legend(loc='best')
plt.show()

# %%
shapiro(results4.resid)
# Out:
# ShapiroResult(statistic=0.8433614373207092, pvalue=4.7908556847988906e-30)

# %%
#pvalue>5%, on accepte la normalité. donc modele validé statistiquement!!!

# %%
y_perd=predictions

# %%
y_perd

# %%
# !pip install neuralprophet

# %%
# !pip install NeuralProphet
# Out:
# ...
#   Using cached neuralprophet-0.8.0-py3-none-any.whl.metadata (9.1 kB)
# ...
#   Using cached captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached holidays-0.48-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached torchmetrics-1.4.0.post0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached grpcio-1.63.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...

# %%
# !pip install NeuralProphet
# Out:
# ...
#   Using cached neuralprophet-0.8.0-py3-none-any.whl.metadata (9.1 kB)
# ...
#   Using cached captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached holidays-0.48-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached torchmetrics-1.4.0.post0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached grpcio-1.63.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...

# %%
import pandas as pd
from neuralprophet import NeuralProphet
import matplotlib.pyplot as plt

# %%
#Télécharger les données des actions
symbols = ['TSLA', 'META']
data = yf.download(symbols, start="2010-06-01", end="2024-05-04")
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Sélectionner uniquement les colonnes nécessaires
data = data['Close'].reset_index()

# %%
# Séparer les données pour chaque action
data_tsla = data[['Date', 'TSLA']].rename(columns={'Date': 'ds', 'TSLA': 'y'})
data_meta = data[['Date', 'META']].rename(columns={'Date': 'ds', 'META': 'y'})

# %%
# Vérifier les données
data_tsla.head()
data_meta.head()
# Out:
# Ticker         ds   y
# 0      2010-06-29 NaN
# 1      2010-06-30 NaN
# 2      2010-07-01 NaN
# 3      2010-07-02 NaN
# 4      2010-07-06 NaN

# %%
# Modèle NeuralProphet pour TSLA
model_np_tsla = NeuralProphet()
model_np_fit_tsla = model_np_tsla.fit(data_tsla, freq='D')
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.328% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 80
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (55) is too small than the required number                     for the learning rate finder (238). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/238 [00:00<?, ?it/s]
# ...

# %%
# Prévision NeuralProphet pour TSLA
future_tsla = model_np_tsla.make_future_dataframe(data_tsla, periods=30)
forecast_tsla = model_np_tsla.predict(future_tsla)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.328% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 55it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
#Modèle NeuralProphet pour META
model_np_meta = NeuralProphet()
model_np_fit_meta = model_np_meta.fit(data_meta, freq='D')
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.328% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.data.processing._handle_missing_data) - Dropped 477 rows with NaNs in 'y' column.
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 80
# ...

# %%
# Préparer les données pour ARIMA pour TSLA
data_tsla_arima = data_tsla.set_index('ds')
data_tsla_arima.index = pd.to_datetime(data_tsla_arima.index)

# %%
# Modèle ARIMA pour TSLA
model_arima_tsla = ARIMA(data_tsla_arima['y'], order=(5,1,0))
model_arima_fit_tsla = model_arima_tsla.fit()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Modèle ARIMA pour TSLA
model_arima_tsla = ARIMA(data_tsla_arima['y'], order=(5,1,0))
model_arima_fit_tsla = model_arima_tsla.fit()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Prévision ARIMA pour TSLA
forecast_arima_tsla = model_arima_fit_tsla.forecast(steps=30)
forecast_arima_index_tsla = pd.date_range(start=data_tsla_arima.index[-1], periods=30, freq='D')
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Convertir en DataFrame pour comparaison
forecast_arima_df_tsla = pd.DataFrame({'ds': forecast_arima_index_tsla, 'y': forecast_arima_tsla.values})

# %%
# Préparer les données pour ARIMA pour META
data_meta_arima = data_meta.set_index('ds')
data_meta_arima.index = pd.to_datetime(data_meta_arima.index)

# %%
# Modèle ARIMA pour META
model_arima_meta = ARIMA(data_meta_arima['y'], order=(5,1,0))
model_arima_fit_meta = model_arima_meta.fit()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Prévision ARIMA pour META
forecast_arima_meta = model_arima_fit_meta.forecast(steps=30)
forecast_arima_index_meta = pd.date_range(start=data_meta_arima.index[-1], periods=30, freq='D')
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\nadin\OneDrive\Bureau\ANACO\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Convertir en DataFrame pour comparaison
forecast_arima_df_meta = pd.DataFrame({'ds': forecast_arima_index_meta, 'y': forecast_arima_meta.values})

# %%
# Affichage des résultats pour TSLA
plt.figure(figsize=(14, 7))
plt.plot(data_tsla['ds'], data_tsla['y'], label='Données réelles TSLA')
plt.plot(forecast_tsla['ds'], forecast_tsla['yhat1'], label='Prévision NeuralProphet TSLA', linestyle='dashed')
plt.plot(forecast_arima_df_tsla['ds'], forecast_arima_df_tsla['y'], label='Prévision ARIMA TSLA', linestyle='dotted')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Prix de clôture TSLA')
plt.title('Comparaison des prévisions: NeuralProphet vs ARIMA pour TSLA')
plt.show()

# %%
# Affichage des résultats pour META
plt.figure(figsize=(14, 7))
plt.plot(data_meta['ds'], data_meta['y'], label='Données réelles META')
plt.plot(forecast_meta['ds'], forecast_meta['yhat1'], label='Prévision NeuralProphet META', linestyle='dashed')
plt.plot(forecast_arima_df_meta['ds'], forecast_arima_df_meta['y'], label='Prévision ARIMA META', linestyle='dotted')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Prix de clôture META')
plt.title('Comparaison des prévisions: NeuralProphet vs ARIMA pour META')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[458], line 4
#       2 plt.figure(figsize=(14, 7))
#       3 plt.plot(data_meta['ds'], data_meta['y'], label='Données réelles META')
# ----> 4 plt.plot(forecast_meta['ds'], forecast_meta['yhat1'], label='Prévision NeuralProphet META', linestyle='dashed')
#       5 plt.plot(forecast_arima_df_meta['ds'], forecast_arima_df_meta['y'], label='Prévision ARIMA META', linestyle='dotted')
#       6 plt.legend()
#
# NameError: name 'forecast_meta' is not defined
